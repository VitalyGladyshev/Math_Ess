# %%
from scipy import stats

# %% [markdown]
# # ДЗ №4 Гладышев В.В.

# %% [markdown]
# ## Задание №1

# %% [markdown]
# О непрерывной равномерно распределённой случайной величине `B` известно, что её дисперсия равна 0.2. Можно ли найти правую границу величины `B` и её среднее значение зная, что левая граница равна 0.5? Если да, найдите их.

# %% [markdown]
# Дисперсия равномерного распределения:
# $$D(X) = \dfrac{(b - a)^2}{12}$$
#
# $\sqrt{12 * D(X)} + a = b\:\:$  известно, что a < b
#
# $\sqrt{12 * 0.2} + 0.5 \approx 2.05\:\:$
#
# Математическое ожидание:
# $$M(X) = \dfrac{a + b}{2}$$
#
# $M(X) = \dfrac{0.5 + 2.05}{2} \approx 1.275$

# %% [markdown]
# ## Задание №2

# %% [markdown]
# Коробки с шоколадом упаковываются автоматически. Их средняя масса равна 1.06 кг. Известно, что 5% коробок имеют массу, меньшую 1 кг. Найдите: а) среднее квадратическое отклонение массы коробки, б) процент коробок, имеющих массу больше 1.1 кг.
#
# _Подсказка_. Найдите такое значение `scale`, для которого значение `cdf(x=1, loc=1.06, scale=scale)` близко к 0.05. Точности 0.0001 будет достаточно.

# %%
x = 1
loc = 1.06
scale = 1
lim = 0.05
pr = 1

def get_prob_print(x, m, s):
    p = stats.norm.cdf(x, m, s)
    print("    p = {:.5f}, сигма: {:.5f}".format(p, scale))
    return p

while(True):
    p1 = get_prob_print(x, loc, scale)

    if p1 > lim:
        pr /= 10
        scale *= pr
    else:
        while(True):
            if p1 > lim:
                if p1 - lim > 0.0001:
                    pr /= 10
                else:
                    break
            scale += pr
            p1 = get_prob_print(x, loc, scale + pr)
        break

print("\nСреднеквадратическое отклонение массы коробки = {:.4f}\n".format(scale))

print("Процент коробок, имеющих массу больше 1.1 кг = {:.2f}%".format((1-stats.norm.cdf(1.1, loc, scale))*100))
# Out:
#     p = 0.47608, сигма: 1.00000
#     p = 0.27425, сигма: 0.10000
#     p = 0.00000, сигма: 0.00100
#     p = 0.00214, сигма: 0.01100
#     p = 0.02647, сигма: 0.02100
#     p = 0.07168, сигма: 0.03100
#     p = 0.03452, сигма: 0.03200
#     p = 0.03881, сигма: 0.03300
#     p = 0.04324, сигма: 0.03400
#     p = 0.04779, сигма: 0.03500
#     p = 0.05244, сигма: 0.03600
#     p = 0.04871, сигма: 0.03610
#     p = 0.04918, сигма: 0.03620
#     p = 0.04964, сигма: 0.03630
#     p = 0.05011, сигма: 0.03640
#     p = 0.04973, сигма: 0.03641
#     p = 0.04978, сигма: 0.03642
#     p = 0.04983, сигма: 0.03643
#     p = 0.04987, сигма: 0.03644
#     p = 0.04992, сигма: 0.03645
#     p = 0.04997, сигма: 0.03646
#     p = 0.05001, сигма: 0.03647
#
# Среднеквадратическое отклонение массы коробки = 0.0365
#
# Процент коробок, имеющих массу больше 1.1 кг = 13.64%

# %% [markdown]
# ## Задание №3

# %% [markdown]
# Коробка содержит 30 конфет. Известно, что масса каждой конфеты распределена равномерно в промежутке от 12 до 14 граммов. Используя центральную предельную теорему, найти вероятность, что масса всей коробки будет: а) меньше 390 граммов, б) больше 395 граммов, в) от 380 до 400 граммов.
#
# Массой самой коробки можно пренебречь.

# %% [markdown]
# Математическое ожидание величины $X$ равно $\dfrac{12 + 14}{2} = 13$. Дисперсия:
# $\dfrac{(14 - 12)^2}{12} = \dfrac{2^2}{12} = \dfrac{1}{3}$. Это означает, что нормальное распределение $Y$ имеет параметры $a = 13$, $\sigma^2 = \dfrac{1}{3n}$.

# %%
n = 30
loc = 13
scale = (1/3*n)**0.05

w1 = 390/n
print("Процент коробок, имеющих массу меньше 390 граммов = {:.2f}%".format((stats.norm.cdf(w1, loc, scale))*100))

w2 = 395/n
print("Процент коробок, имеющих массу больше 395 граммов = {:.2f}%".format((1 - stats.norm.cdf(w2, loc, scale))*100))

w3 = 380/n
per3 = (1 - stats.norm.cdf(w3, loc, scale))*100
print("Процент коробок, имеющих массу больше 380 граммов = {:.2f}%".format(per3))

w4 = 400/n
per4 = (1 - stats.norm.cdf(w4, loc, scale))*100
print("Процент коробок, имеющих массу больше 400 граммов = {:.2f}%".format(per4))

print("Процент коробок, имеющих массу от 380 до 400 граммов = {:.2f}%".format(per3-per4))
# Out:
# Процент коробок, имеющих массу меньше 390 граммов = 50.00%
# Процент коробок, имеющих массу больше 395 граммов = 44.10%
# Процент коробок, имеющих массу больше 380 граммов = 61.68%
# Процент коробок, имеющих массу больше 400 граммов = 38.32%
# Процент коробок, имеющих массу от 380 до 400 граммов = 23.36%

# %% [markdown]
# ## От преподавателя:
# Добрый день) Задания 1 и 2 решены верно) В третьем не совсем так) У вас же масса коробки -- это сумма случайных величин, а не их среднее арифметическое) Соответственно, и ЦПТ нужно применять именно для суммы (это первая версия из двух, которые были у нас на занятии).
