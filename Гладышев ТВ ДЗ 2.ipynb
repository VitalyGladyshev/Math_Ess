# %%
import numpy as np

# %%
def combinations(n: int, k: int) -> int:
    """Число сочетаний.
    """
    
    return np.math.factorial(n) // (np.math.factorial(k) * np.math.factorial(n - k))

# %%
def poisson_proba(k: int, lambda_: float) -> float:
    """Формула Пуассона.
    """
    
    return (lambda_ ** k) * (np.exp(-lambda_)) / np.math.factorial(k)

# %% [markdown]
# # ДЗ №2 Гладышев В.В.

# %% [markdown]
# ## Задание №1

# %% [markdown]
# Контрольная работа состоит из пяти вопросов. На каждый вопрос приведено четыре варианта ответа, один из которых правильный. Составьте закон распределения числа правильных ответов при простом угадывании. Найдите `M(X)`, `D(X)`.

# %%
n = 5
p = 0.25
a = np.arange(n+1)
prb = np.zeros(n+1)

for i in a:
    prb[i] = combinations(n, i)*p**i*(1-p)**(n-i)
    print("Правильных ответов: {} вероятность = {}/1024:\t{:.4f}".format(i, combinations(n, i)*3**(n-i), prb[i]))
m = a@prb
print("M(X): {}; {}".format(m, n*p))
print("D(X): {}; {}".format((a-m)**2@prb, n*p*(1-p)))
# Out:
# Правильных ответов: 0 вероятность = 243/1024:	0.2373
# Правильных ответов: 1 вероятность = 405/1024:	0.3955
# Правильных ответов: 2 вероятность = 270/1024:	0.2637
# Правильных ответов: 3 вероятность = 90/1024:	0.0879
# Правильных ответов: 4 вероятность = 15/1024:	0.0146
# Правильных ответов: 5 вероятность = 1/1024:	0.0010
# M(X): 1.25; 1.25
# D(X): 0.9375; 0.9375

# %% [markdown]
# ## Задание №2

# %% [markdown]
# Пользователь получает в среднем 10 писем со спамом на свой почтовый ящик за сутки. Найти число `N`, такое, что с вероятностью 0.95 пользователь получит не более `N` писем со спамом за текущий день.

# %%
lambda_ = 10
prb = 0

for i in range(1, 100):
    prb += poisson_proba(k=i, lambda_=lambda_)
    print("Вероятность: {:.4f}\tN: {}".format(prb, i))
    if prb > 0.95:
        break
# Out:
# Вероятность: 0.0005	N: 1
# Вероятность: 0.0027	N: 2
# Вероятность: 0.0103	N: 3
# Вероятность: 0.0292	N: 4
# Вероятность: 0.0670	N: 5
# Вероятность: 0.1301	N: 6
# Вероятность: 0.2202	N: 7
# Вероятность: 0.3328	N: 8
# Вероятность: 0.4579	N: 9
# Вероятность: 0.5830	N: 10
# Вероятность: 0.6967	N: 11
# Вероятность: 0.7915	N: 12
# Вероятность: 0.8644	N: 13
# Вероятность: 0.9165	N: 14
# Вероятность: 0.9512	N: 15

# %% [markdown]
# ## Задание №3

# %% [markdown]
# Производятся выстрелы по мишени. Вероятность попадания в мишень при одном выстреле равна 0.01. Сколько выстрелов нужно сделать чтобы быть уверенным с вероятностью 0.9, что хотя бы 6 раз будет совершено попадание?

# %%
p = 0.01
n_lst = []

for ind in range(6, 1001):
    n_tmp = ind*p-(1-p)
    if n_tmp >=6 and n_tmp < 7:
        n_lst.append(ind)
print(n_lst)

for n in n_lst:
    bt = n*p-(1-p)
    ab = n*p+p
    print("{}: {:.2f} <= n < {:.2f} P(x): {:.4f}".format(n, bt, ab, combinations(n, round(bt))*(p**round(bt))*((1-p)**(n-round(bt)))))
# Out:
# [699, 700, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798]
# 699: 6.00 <= n < 7.00 P(x): 0.1498
# 700: 6.01 <= n < 7.01 P(x): 0.1495
# 701: 6.02 <= n < 7.02 P(x): 0.1493
# 702: 6.03 <= n < 7.03 P(x): 0.1491
# 703: 6.04 <= n < 7.04 P(x): 0.1489
# 704: 6.05 <= n < 7.05 P(x): 0.1487
# 705: 6.06 <= n < 7.06 P(x): 0.1484
# 706: 6.07 <= n < 7.07 P(x): 0.1482
# 707: 6.08 <= n < 7.08 P(x): 0.1480
# 708: 6.09 <= n < 7.09 P(x): 0.1478
# 709: 6.10 <= n < 7.10 P(x): 0.1475
# 710: 6.11 <= n < 7.11 P(x): 0.1473
# 711: 6.12 <= n < 7.12 P(x): 0.1471
# ...
